# %%
import dataikuapi

# %%
host = "http://localhost:12000/"
apiKey = "lmdmIhchhIJqjrYTtKQ4Ty4fqMQU8EJB"
client = dataikuapi.DSSClient(host, apiKey)

# %%
handle = dataikuapi.dss.statistics.DSSStatisticsWorksheet(client, "NEWCCDISCOVERYSETUP", dataset_name="transactions_joined_prepared", worksheet_id="QoISNh4LAe")
worksheet_results = handle.run_worksheet()

# %%
worksheet_results.get_raw()
# Out:
# {'type': 'worksheet_root',
#  'results': [{'type': 'univariate_header',
#    'results': [{'type': 'column_card',
#      'column': {'name': 'authorized_flag', 'type': 'CONTINUOUS'},
#      'results': [{'type': 'numerical_histogram',
#        'histogram': {'bins': [{'type': 'interval',
#           'column': 'authorized_flag',
#           'closed': 'LEFT',
#           'left': 0.0,
#           'right': 0.058333333333333334},
#          {'type': 'interval',
#           'column': 'authorized_flag',
#           'closed': 'LEFT',
#           'left': 0.058333333333333334,
#           'right': 0.11666666666666667},
#          {'type': 'interval',
#           'column': 'authorized_flag',
#           'closed': 'LEFT',
#           'left': 0.11666666666666667,
#           'right': 0.175},
#          {'type': 'interval',
#           'column': 'authorized_flag',
#           'closed': 'LEFT',
#           'left': 0.175,
#           'right': 0.23333333333333334},
#          {'type': 'interval',
# ...
